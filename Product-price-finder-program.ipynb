# %%
product_prices={"Pen":10,"Notebook":50,"Bottel":100}
import pyttsx3
engine = pyttsx3.init()
rate=engine.getProperty('rate')
engine.setProperty('rate',75)
engine.say("Hy tabish bhai ")
engine.runAndWait()

# %%
def say(text):
    engine.say(text)
    engine.runAndWait()

say("Enter the product name to search")
product_name=input("Enter the product name to search").capitalize()
if product_name in product_prices:
    print(f"Price for {product_name} is {product_prices[product_name]}") 
    say(f"Price for {product_name} is {product_prices[product_name]}")
else:
    print("product is not available do you want to update the prices ")
    say("product is not available do you want to update the prices ")
    print("yes or no")
    say("yes or no")
    choice=input("Enter your choice").lower()
    say("Enter your chice")
    if choice=="yes":
        produce_price=int(input("Enter price of product"))
        product_prices[product_name]=produce_price
        print("price update successfully")
        say("price update successfully")
    elif choice=="no":
        print("Not updating the value")
        say("Not updating the value")
        print("Thank you")
        say("Thank you")
    else:
        print("good bye") 
product_prices
# Out:
# Enter the product name to search pen
# Price for Pen is 10
# {'Pen': 10, 'Notebook': 50, 'Bottel': 100}
